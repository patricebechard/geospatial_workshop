# %% [markdown]
# # Destination Prediction
#
# We want to predict the destination of a driver based on the beginning of its trip. We will use various fractions of the trip from the beginning and see how they allow us to better predict the destination.

# %%
# %pylab inline
import torch
from torch import nn
import torch.nn.functional as F
from torch import optim

import numpy as np
import os
import sys
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from src.destination_prediction.utils import *
from src.destination_prediction.model import DestinationLSTM, DestinationLSTMClf
from src.destination_prediction.train import train, evaluate, train_clf, evaluate_clf

# %% [markdown]
# ### Downloading the dataset
# We first download the GeoLife Trajectories dataset from Microsoft.

# %%
download_data()
# Out:
# Data has already been downloaded!

# %% [markdown]
# ### Analyzing the trip length distribution
# We first have a look at the data to see what's the distribution of the trip lengths.

# %%
show_trip_length_distribution()
# Out:
# Creating a histogram showing the trip length distribution...

# %% [markdown]
# We decide to keep trips of length between 50 and 2000 to train our model. (I already cropped the trips that were shorter or longer than that in the histogram)

# %% [markdown]
# ### Analyzing GPS position distribution
# Let's see where the majority of the trips are concentrated

# %%
show_position_distribution()
# Out:
# Creating histograms showing the position distribution...

# %% [markdown]
# We find that the majority of trips are between longitudes 116.25 and 116.50 and between latitudes 39.85 and 40.10. This is located in Beijing, China. We decide only to keep these values. This will help use reduce the search space in order to make better predictions.

# %% [markdown]
# ### Splitting the dataset into train, valid, test sets
# This creates `train.json`, `valid.json` and `test.json` files containing the datasets. We standardize and randomize the data at the same time.

# %%
create_datasets()
# Out:
# Splitting the dataset into train, valid, dev ...
# Saving the datasets created...

# %% [markdown]
# ### Loading the data
#
# We first load the data from the json files and then we split them in batches to accelerate the LSTM's training. Before splitting into batches, we sort the trips by length so that none of the trips are padded too much.

# %%
import json

# loading datasets from json file
with open(os.path.join(os.getcwd(), "geolife_trajectories", "train.json")) as json_data:
    train_dset = json.load(json_data)

with open(os.path.join(os.getcwd(), "geolife_trajectories", "valid.json")) as json_data:    
    valid_dset = json.load(json_data)
    
with open(os.path.join(os.getcwd(), "geolife_trajectories", "test.json")) as json_data:
    test_dset = json.load(json_data)
    
with open(os.path.join(os.getcwd(), "geolife_trajectories", "mean_std.json")) as json_data:
    mean_std_data = json.load(json_data)

# %%
#creating batched version of the datasets
batched_train_dset = create_batched_dset(train_dset, batch_size=8)
batched_valid_dset = create_batched_dset(valid_dset, batch_size=1)
batched_test_dset = create_batched_dset(test_dset, batch_size=1)

# %% [markdown]
# ### Creating our model
# We use a LSTM network as our model to predict the destination of the trip. We use this model because the length of trips varies and LSTMs can take inputs of variable lengths. We have two different linear layers to predict both the longitude and the latitude of the destination.

# %%
model = DestinationLSTM().to(device)

# %% [markdown]
# ### Training our model
# We train the model using different fractions of the beginning of our trip.
#
# We first sort the trips of each dataset by length so that the training time is reduced a bit

# %%
train(model, batched_train_dset, mean_std_data, batched_valid_dset, n_epochs=100, start_lr=1e-4, trip_frac=1.)
# Out:
# Epoch 0 ----- mean distance error : 3.677 ----- mean valid distance error : 3.937
# Epoch 1 ----- mean distance error : 3.594 ----- mean valid distance error : 3.902
# Epoch 2 ----- mean distance error : 3.570 ----- mean valid distance error : 3.875
# Epoch 3 ----- mean distance error : 3.555 ----- mean valid distance error : 3.855
# Epoch 4 ----- mean distance error : 3.544 ----- mean valid distance error : 3.841
# Epoch 5 ----- mean distance error : 3.534 ----- mean valid distance error : 3.829
# Epoch 6 ----- mean distance error : 3.525 ----- mean valid distance error : 3.819
# Epoch 7 ----- mean distance error : 3.516 ----- mean valid distance error : 3.810
# Epoch 8 ----- mean distance error : 3.506 ----- mean valid distance error : 3.799
# Epoch 9 ----- mean distance error : 3.496 ----- mean valid distance error : 3.788
# Epoch 10 ----- mean distance error : 3.485 ----- mean valid distance error : 3.776
# Epoch 11 ----- mean distance error : 3.473 ----- mean valid distance error : 3.765
# Epoch 12 ----- mean distance error : 3.463 ----- mean valid distance error : 3.755
# Epoch 13 ----- mean distance error : 3.453 ----- mean valid distance error : 3.745
# Epoch 14 ----- mean distance error : 3.445 ----- mean valid distance error : 3.736
# Epoch 15 ----- mean distance error : 3.438 ----- mean valid distance error : 3.728
# Epoch 16 ----- mean distance error : 3.431 ----- mean valid distance error : 3.721
# Epoch 17 ----- mean distance error : 3.427 ----- mean valid distance error : 3.716
# Epoch 18 ----- mean distance error : 3.423 ----- mean valid distance error : 3.712
# Epoch 19 ----- mean distance error : 3.421 ----- mean valid distance error : 3.710
# Epoch 20 ----- mean distance error : 3.420 ----- mean valid distance error : 3.708
# Epoch 21 ----- mean distance error : 3.419 ----- mean valid distance error : 3.707
# Epoch 22 ----- mean distance error : 3.419 ----- mean valid distance error : 3.707
# Epoch 23 ----- mean distance error : 3.418 ----- mean valid distance error : 3.706
# Epoch 24 ----- mean distance error : 3.417 ----- mean valid distance error : 3.705
# Epoch 25 ----- mean distance error : 3.416 ----- mean valid distance error : 3.703
# Epoch 26 ----- mean distance error : 3.414 ----- mean valid distance error : 3.700
# Epoch 27 ----- mean distance error : 3.412 ----- mean valid distance error : 3.697
# Epoch 28 ----- mean distance error : 3.410 ----- mean valid distance error : 3.694
# Epoch 29 ----- mean distance error : 3.408 ----- mean valid distance error : 3.693
# Epoch 30 ----- mean distance error : 3.405 ----- mean valid distance error : 3.691
# Epoch 31 ----- mean distance error : 3.404 ----- mean valid distance error : 3.689
# Epoch 32 ----- mean distance error : 3.402 ----- mean valid distance error : 3.688
# Epoch 33 ----- mean distance error : 3.398 ----- mean valid distance error : 3.682
# Epoch 34 ----- mean distance error : 3.394 ----- mean valid distance error : 3.680
# Epoch 35 ----- mean distance error : 3.392 ----- mean valid distance error : 3.678
# Epoch 36 ----- mean distance error : 3.391 ----- mean valid distance error : 3.676
# Epoch 37 ----- mean distance error : 3.389 ----- mean valid distance error : 3.676
# Epoch 38 ----- mean distance error : 3.389 ----- mean valid distance error : 3.676
# Epoch 39 ----- mean distance error : 3.390 ----- mean valid distance error : 3.678
# Epoch 40 ----- mean distance error : 3.391 ----- mean valid distance error : 3.679
# Epoch 41 ----- mean distance error : 3.392 ----- mean valid distance error : 3.680
# Epoch 42 ----- mean distance error : 3.391 ----- mean valid distance error : 3.678
# Epoch 43 ----- mean distance error : 3.396 ----- mean valid distance error : 3.683
# Epoch 44 ----- mean distance error : 3.394 ----- mean valid distance error : 3.682
# Epoch 45 ----- mean distance error : 3.400 ----- mean valid distance error : 3.686
# Epoch 46 ----- mean distance error : 3.398 ----- mean valid distance error : 3.684
# Epoch 47 ----- mean distance error : 3.403 ----- mean valid distance error : 3.689
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-037ab53a7183> in <module>
# ----> 1 train(model, batched_train_dset, mean_std_data, batched_valid_dset, n_epochs=100, start_lr=1e-4, trip_frac=1.)
#
# /media/patrice/PROJECTS/Intact/geospatial_workshop/src/destination_prediction/train.py in train(model, train_set, mean_std_data, valid_set, n_epochs, start_lr, trip_frac, lr_decay)
#      46             optimizer.zero_grad()
#      47
# ---> 48             out_lat, out_long = model(inputs)
#      49
#      50             loss = criterion(out_lat.squeeze(), targets[:,0])
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# /media/patrice/PROJECTS/Intact/geospatial_workshop/src/destination_prediction/model.py in forward(self, x)
#      32         self._init_hidden(batch_size=x.shape[1])
#      33
# ---> 34         x, (self.hidden, self.cell) = self.lstm(x, (self.hidden, self.cell))
#      35
#      36
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     190             flat_weight=flat_weight
#     191         )
# --> 192         output, hidden = func(input, self.all_weights, hx, batch_sizes)
#     193         if is_packed:
#     194             output = PackedSequence(output, batch_sizes)
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, *fargs, **fkwargs)
#     322             func = decorator(func)
#     323
# --> 324         return func(input, *fargs, **fkwargs)
#     325
#     326     return forward
#
# ~/anaconda3/envs/pytorch/lib/python3.6/site-packages/torch/nn/_functions/rnn.py in forward(input, weight, hx, batch_sizes)
#     286             batch_first, dropout, train, bool(bidirectional),
#     287             list(batch_sizes.data) if variable_length else (),
# --> 288             dropout_ts)
#     289
#     290         if cx is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Show results on the map
#
# Here we show the predicted destination given the beginning of a trip.

# %%
# pick a trip
trip = batched_valid_dset[1]
trajectory = trip[0]
end = trip[1]

# preprocess it
trip_frac = 0.1
inputs = trajectory.to(device)
targets = end.to(device)

# truncate trip to keep only beginning
inputs = inputs[:int(trip_frac*inputs.shape[0])]

# standardize inputs and targets
inputs[:,:,0] = (inputs[:,:,0] - mean_std_data["mean_lat"]) / mean_std_data["std_lat"]
inputs[:,:,1] = (inputs[:,:,1] - mean_std_data["mean_long"]) / mean_std_data["std_long"]

targets[:,0] = (targets[:,0] - mean_std_data["mean_lat"]) / mean_std_data["std_lat"]
targets[:,1] = (targets[:,1] - mean_std_data["mean_long"]) / mean_std_data["std_long"]

# predict output
out_lat, out_long = model(inputs)

# compute mean distance error (km)
# n_pts += inputs.shape[1]

out_lat = out_lat.squeeze().data.to('cpu').numpy()
out_long = out_long.squeeze().data.to('cpu').numpy()
tgt_lat = targets[:,0].squeeze().to('cpu').numpy()
tgt_long = targets[:,1].squeeze().to('cpu').numpy()

# un-standardize data
out_lat = out_lat * mean_std_data["std_lat"] + mean_std_data["mean_lat"]
out_long = out_long * mean_std_data["std_long"] + mean_std_data["mean_long"]
tgt_lat = tgt_lat * mean_std_data["std_lat"] + mean_std_data["mean_lat"]
tgt_long = tgt_long * mean_std_data["std_long"] + mean_std_data["mean_long"]

# print map of Beijing
img=plt.imread('figures/map.png')
plt.figure(figsize = (24.32,31.64))
imgplot = plt.imshow(img, extent=(116.25, 116.5, 39.85, 40.1))

# plot trip, destination and predicted destination

print(trajectory[:,:,0].numpy().T)

plt.plot(trajectory[:,:,1].numpy(), trajectory[:,:,0].numpy(), 'r')
plt.scatter(trajectory[0,:,1].numpy(), trajectory[0,:,0].numpy(), c='k', marker='v', s=500, label="Trip beginning")
plt.scatter(out_long, out_lat, c='b', marker='*', s=500, label="Predicted trip end")
plt.scatter(tgt_long, tgt_lat, c='r', marker='*', s=500, label="Trip end")

plt.legend(fancybox=True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-cdbf6eb5f869> in <module>
#      20
#      21 # predict output
# ---> 22 out_lat, out_long = model(inputs)
#      23
#      24 # compute mean distance error (km)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
trip = batched_train_dset[0][0][:,-1]
target = batched_train_dset[0][-1][-1]

print(trip)
print(target)

output = model(trip.unsqueeze(1).to(device))
print(output)
# Out:
# tensor([[ 40.0774, 116.3288],
#         [ 40.0773, 116.3291],
#         [ 40.0771, 116.3289],
#         [ 40.0771, 116.3279],
#         [ 40.0768, 116.3278],
#         [ 40.0765, 116.3279],
#         [ 40.0762, 116.3279],
#         [ 40.0759, 116.3280],
#         [ 40.0756, 116.3281],
#         [ 40.0753, 116.3281],
#         [ 40.0749, 116.3282],
#         [ 40.0746, 116.3282],
#         [ 40.0742, 116.3283],
#         [ 40.0738, 116.3284],
#         [ 40.0735, 116.3284],
#         [ 40.0731, 116.3285],
#         [ 40.0728, 116.3285],
#         [ 40.0725, 116.3286],
#         [ 40.0722, 116.3286],
#         [ 40.0719, 116.3287],
#         [ 40.0715, 116.3287],
#         [ 40.0713, 116.3288],
#         [ 40.0709, 116.3288],
#         [ 40.0705, 116.3288],
#         [ 40.0702, 116.3289],
#         [ 40.0699, 116.3291],
#         [ 40.0698, 116.3297],
#         [ 40.0696, 116.3295],
#         [ 40.0695, 116.3298],
#         [ 40.0694, 116.3301],
#         [ 40.0695, 116.3302],
#         [ 40.0695, 116.3280],
#         [ 40.0695, 116.3132],
#         [ 40.0695, 116.3133],
#         [ 40.0696, 116.3056],
#         [ 40.0708, 116.3018],
#         [ 40.0709, 116.3009],
#         [ 40.0493, 116.3017],
#         [ 40.0391, 116.3080],
#         [ 40.0386, 116.3086],
#         [ 40.0379, 116.3096],
#         [ 40.0365, 116.3112],
#         [ 40.0345, 116.3127],
#         [ 40.0317, 116.3139],
#         [ 40.0172, 116.3202],
#         [ 40.0082, 116.3300],
#         [ 40.0062, 116.3310],
#         [ 40.0051, 116.3311],
#         [ 39.9976, 116.3314],
#         [ 39.9921, 116.3317],
#         [ 39.9916, 116.3317],
#         [ 39.9854, 116.3319],
#         [ 39.9756, 116.3336],
#         [ 39.9750, 116.3342],
#         [ 39.9757, 116.3336],
#         [ 39.9757, 116.3335],
#         [ 39.9753, 116.3336],
#         [ 39.9754, 116.3331],
#         [ 39.9754, 116.3326],
#         [ 39.9754, 116.3323],
#         [ 39.9754, 116.3320],
#         [ 39.9756, 116.3317],
#         [ 39.9758, 116.3314],
#         [ 39.9757, 116.3311]])
# tensor([ 39.9757, 116.3311])
# (tensor([[1.2773]], device='cuda:0', grad_fn=<ThAddmmBackward>), tensor([[-0.3788]], device='cuda:0', grad_fn=<ThAddmmBackward>))

# %%
# instead of doing a regression on the longitudes and latitudes, could do a classification on the nearest destination nodes

import osmnx as ox

north, south, east, west = (40.10, 39.85, 116.50, 116.25)
G = ox.graph_from_bbox(north, south, east, west, network_type='all')

# %%
import copy
import networkx as nx

# creating mapping to have nodes labeled from 0 to nb_of_nodes
mapping = {}
for i, node in enumerate(G.nodes):
    mapping[node] = i

# creating new graph with said mapping
H = nx.relabel_nodes(G, mapping)

# %%
model = DestinationLSTMClf(graph=H).to(device)

# %%
train_clf(model, batched_train_dset, mean_std_data, batched_valid_dset, n_epochs=100, start_lr=1e-3, trip_frac=1.)
# Out:
# Epoch 0 ----- mean distance error : 3.938 ----- mean valid distance error : 4.473
# Epoch 1 ----- mean distance error : 3.734 ----- mean valid distance error : 4.584
# Epoch 2 ----- mean distance error : 3.775 ----- mean valid distance error : 10.246
# Epoch 3 ----- mean distance error : 3.854 ----- mean valid distance error : 11.659
# Epoch 4 ----- mean distance error : 3.766 ----- mean valid distance error : 3.317
# Epoch 5 ----- mean distance error : 3.720 ----- mean valid distance error : 10.910
# Epoch 6 ----- mean distance error : 3.737 ----- mean valid distance error : 3.832
# Epoch 7 ----- mean distance error : 3.784 ----- mean valid distance error : 11.659
# Epoch 8 ----- mean distance error : 3.818 ----- mean valid distance error : 3.465
# Epoch 9 ----- mean distance error : 4.409 ----- mean valid distance error : 9.436
# Epoch 10 ----- mean distance error : 3.797 ----- mean valid distance error : 5.199
# Epoch 11 ----- mean distance error : 3.714 ----- mean valid distance error : 3.674
# Epoch 12 ----- mean distance error : 3.975 ----- mean valid distance error : 11.522
# Epoch 13 ----- mean distance error : 3.903 ----- mean valid distance error : 3.934
# Epoch 14 ----- mean distance error : 3.867 ----- mean valid distance error : 7.260
# Epoch 15 ----- mean distance error : 3.857 ----- mean valid distance error : 8.938
# Epoch 16 ----- mean distance error : 3.780 ----- mean valid distance error : 8.888
# Epoch 17 ----- mean distance error : 3.740 ----- mean valid distance error : 7.167
# Epoch 18 ----- mean distance error : 3.666 ----- mean valid distance error : 3.584
# Epoch 19 ----- mean distance error : 3.537 ----- mean valid distance error : 2.674
# Epoch 20 ----- mean distance error : 3.425 ----- mean valid distance error : 3.864
# Epoch 21 ----- mean distance error : 3.495 ----- mean valid distance error : 2.528
# Epoch 22 ----- mean distance error : 3.340 ----- mean valid distance error : 6.821
# Epoch 23 ----- mean distance error : 4.034 ----- mean valid distance error : 6.576
# Epoch 24 ----- mean distance error : 3.488 ----- mean valid distance error : 2.819
# Epoch 25 ----- mean distance error : 3.221 ----- mean valid distance error : 3.186
# Epoch 26 ----- mean distance error : 3.283 ----- mean valid distance error : 6.446
# Epoch 27 ----- mean distance error : 3.110 ----- mean valid distance error : 2.049
# Epoch 28 ----- mean distance error : 2.996 ----- mean valid distance error : 3.639
# Epoch 29 ----- mean distance error : 2.705 ----- mean valid distance error : 8.916
# Epoch 30 ----- mean distance error : 3.191 ----- mean valid distance error : 2.577
# Epoch 31 ----- mean distance error : 2.988 ----- mean valid distance error : 3.024
# Epoch 32 ----- mean distance error : 3.219 ----- mean valid distance error : 3.804
# Epoch 33 ----- mean distance error : 2.744 ----- mean valid distance error : 1.843
# Epoch 34 ----- mean distance error : 3.097 ----- mean valid distance error : 4.446
# Epoch 35 ----- mean distance error : 2.648 ----- mean valid distance error : 2.091
# Epoch 36 ----- mean distance error : 2.792 ----- mean valid distance error : 4.051
# Epoch 37 ----- mean distance error : 2.663 ----- mean valid distance error : 1.623
# Epoch 38 ----- mean distance error : 2.539 ----- mean valid distance error : 3.206
# Epoch 39 ----- mean distance error : 2.984 ----- mean valid distance error : 6.199
# Epoch 40 ----- mean distance error : 2.387 ----- mean valid distance error : 2.448
# Epoch 41 ----- mean distance error : 2.418 ----- mean valid distance error : 3.853
# Epoch 42 ----- mean distance error : 2.669 ----- mean valid distance error : 3.139
# Epoch 43 ----- mean distance error : 2.255 ----- mean valid distance error : 6.264
# Epoch 44 ----- mean distance error : 2.654 ----- mean valid distance error : 2.539
# Epoch 45 ----- mean distance error : 2.205 ----- mean valid distance error : 5.843
# Epoch 46 ----- mean distance error : 2.354 ----- mean valid distance error : 2.444
# Epoch 47 ----- mean distance error : 2.002 ----- mean valid distance error : 1.260
# Epoch 48 ----- mean distance error : 1.865 ----- mean valid distance error : 2.966
# Epoch 49 ----- mean distance error : 1.966 ----- mean valid distance error : 1.184
# Epoch 50 ----- mean distance error : 2.407 ----- mean valid distance error : 2.192
# Epoch 51 ----- mean distance error : 2.205 ----- mean valid distance error : 4.750
# Epoch 52 ----- mean distance error : 2.293 ----- mean valid distance error : 6.209
# Epoch 53 ----- mean distance error : 2.407 ----- mean valid distance error : 1.860
# Epoch 54 ----- mean distance error : 2.792 ----- mean valid distance error : 1.385
# Epoch 55 ----- mean distance error : 2.349 ----- mean valid distance error : 1.528
# Epoch 56 ----- mean distance error : 2.300 ----- mean valid distance error : 2.425
# Epoch 57 ----- mean distance error : 2.357 ----- mean valid distance error : 1.353
# Epoch 58 ----- mean distance error : 2.270 ----- mean valid distance error : 2.079
# Epoch 59 ----- mean distance error : 1.985 ----- mean valid distance error : 1.047
# Epoch 60 ----- mean distance error : 1.815 ----- mean valid distance error : 1.493
# Epoch 61 ----- mean distance error : 1.874 ----- mean valid distance error : 1.287
# Epoch 62 ----- mean distance error : 1.839 ----- mean valid distance error : 1.181
# Epoch 63 ----- mean distance error : 1.937 ----- mean valid distance error : 1.518
# Epoch 64 ----- mean distance error : 1.899 ----- mean valid distance error : 1.415
# Epoch 65 ----- mean distance error : 1.965 ----- mean valid distance error : 1.543
# Epoch 66 ----- mean distance error : 2.447 ----- mean valid distance error : 2.394
# Epoch 67 ----- mean distance error : 2.241 ----- mean valid distance error : 1.554
# Epoch 68 ----- mean distance error : 2.092 ----- mean valid distance error : 1.725
# Epoch 69 ----- mean distance error : 2.457 ----- mean valid distance error : 1.089
# Epoch 70 ----- mean distance error : 1.730 ----- mean valid distance error : 1.244
# Epoch 71 ----- mean distance error : 1.657 ----- mean valid distance error : 1.596
# Epoch 72 ----- mean distance error : 1.614 ----- mean valid distance error : 1.915
# Epoch 73 ----- mean distance error : 1.827 ----- mean valid distance error : 2.026
# Epoch 74 ----- mean distance error : 2.242 ----- mean valid distance error : 1.097
# Epoch 75 ----- mean distance error : 1.707 ----- mean valid distance error : 0.962
# Epoch 76 ----- mean distance error : 1.646 ----- mean valid distance error : 1.196
# Epoch 77 ----- mean distance error : 1.877 ----- mean valid distance error : 1.535
# Epoch 78 ----- mean distance error : 1.602 ----- mean valid distance error : 0.838
# Epoch 79 ----- mean distance error : 1.820 ----- mean valid distance error : 1.946
# Epoch 80 ----- mean distance error : 2.663 ----- mean valid distance error : 1.550
# Epoch 81 ----- mean distance error : 2.170 ----- mean valid distance error : 2.294
# Epoch 82 ----- mean distance error : 1.928 ----- mean valid distance error : 1.264
# Epoch 83 ----- mean distance error : 1.788 ----- mean valid distance error : 0.924
# Epoch 84 ----- mean distance error : 1.615 ----- mean valid distance error : 1.052
# Epoch 85 ----- mean distance error : 1.647 ----- mean valid distance error : 1.065
# Epoch 86 ----- mean distance error : 1.505 ----- mean valid distance error : 1.037
# Epoch 87 ----- mean distance error : 1.543 ----- mean valid distance error : 1.016
# Epoch 88 ----- mean distance error : 1.464 ----- mean valid distance error : 1.261
# Epoch 89 ----- mean distance error : 1.695 ----- mean valid distance error : 0.949
# Epoch 90 ----- mean distance error : 1.505 ----- mean valid distance error : 0.957
# Epoch 91 ----- mean distance error : 1.503 ----- mean valid distance error : 1.103
# Epoch 92 ----- mean distance error : 1.512 ----- mean valid distance error : 0.918
# Epoch 93 ----- mean distance error : 1.341 ----- mean valid distance error : 0.857
# Epoch 94 ----- mean distance error : 1.319 ----- mean valid distance error : 1.225
# Epoch 95 ----- mean distance error : 1.314 ----- mean valid distance error : 0.943
# Epoch 96 ----- mean distance error : 1.471 ----- mean valid distance error : 1.223
# Epoch 97 ----- mean distance error : 1.281 ----- mean valid distance error : 0.922
# Epoch 98 ----- mean distance error : 1.260 ----- mean valid distance error : 1.885
# Epoch 99 ----- mean distance error : 1.340 ----- mean valid distance error : 0.994

# %%
model = DestinationLSTMClf(graph=H).to(device)
train_clf(model, [batched_train_dset[0]], mean_std_data, [batched_valid_dset[0]], n_epochs=100, start_lr=1e-3, trip_frac=1.)
# Out:
# Epoch 0 ----- mean distance error : 12.068 ----- mean valid distance error : 15.015
# Epoch 1 ----- mean distance error : 12.068 ----- mean valid distance error : 15.015
# Epoch 2 ----- mean distance error : 9.021 ----- mean valid distance error : 0.447
# Epoch 3 ----- mean distance error : 3.204 ----- mean valid distance error : 0.447
# Epoch 4 ----- mean distance error : 2.853 ----- mean valid distance error : 0.447
# Epoch 5 ----- mean distance error : 2.853 ----- mean valid distance error : 0.447
# Epoch 6 ----- mean distance error : 2.853 ----- mean valid distance error : 0.447
# Epoch 7 ----- mean distance error : 2.853 ----- mean valid distance error : 0.447
# Epoch 8 ----- mean distance error : 2.853 ----- mean valid distance error : 0.447
# Epoch 9 ----- mean distance error : 2.853 ----- mean valid distance error : 0.447
# Epoch 10 ----- mean distance error : 1.578 ----- mean valid distance error : 0.447
# Epoch 11 ----- mean distance error : 1.578 ----- mean valid distance error : 0.447
# Epoch 12 ----- mean distance error : 1.578 ----- mean valid distance error : 0.447
# Epoch 13 ----- mean distance error : 1.704 ----- mean valid distance error : 0.447
# Epoch 14 ----- mean distance error : 1.704 ----- mean valid distance error : 0.447
# Epoch 15 ----- mean distance error : 1.704 ----- mean valid distance error : 0.447
# Epoch 16 ----- mean distance error : 1.704 ----- mean valid distance error : 0.447
# Epoch 17 ----- mean distance error : 1.704 ----- mean valid distance error : 0.447
# Epoch 18 ----- mean distance error : 1.704 ----- mean valid distance error : 0.447
# Epoch 19 ----- mean distance error : 1.704 ----- mean valid distance error : 0.447
# Epoch 20 ----- mean distance error : 1.704 ----- mean valid distance error : 0.447
# Epoch 21 ----- mean distance error : 1.704 ----- mean valid distance error : 0.447
# Epoch 22 ----- mean distance error : 1.704 ----- mean valid distance error : 0.447
# Epoch 23 ----- mean distance error : 1.704 ----- mean valid distance error : 3.544
# Epoch 24 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 25 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 26 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 27 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 28 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 29 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 30 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 31 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 32 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 33 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 34 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 35 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 36 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 37 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 38 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 39 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 40 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 41 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 42 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 43 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 44 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 45 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 46 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 47 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 48 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 49 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 50 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 51 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 52 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 53 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 54 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 55 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 56 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 57 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 58 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 59 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 60 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 61 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 62 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 63 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 64 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 65 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 66 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 67 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 68 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 69 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 70 ----- mean distance error : 1.707 ----- mean valid distance error : 0.447
# Epoch 71 ----- mean distance error : 1.704 ----- mean valid distance error : 3.544
# Epoch 72 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 73 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 74 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 75 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 76 ----- mean distance error : 1.707 ----- mean valid distance error : 3.544
# Epoch 77 ----- mean distance error : 1.707 ----- mean valid distance error : 0.447
# Epoch 78 ----- mean distance error : 1.704 ----- mean valid distance error : 3.544
# Epoch 79 ----- mean distance error : 1.707 ----- mean valid distance error : 0.447
# Epoch 80 ----- mean distance error : 1.578 ----- mean valid distance error : 3.544
# Epoch 81 ----- mean distance error : 1.581 ----- mean valid distance error : 0.447
# Epoch 82 ----- mean distance error : 1.578 ----- mean valid distance error : 3.544
# Epoch 83 ----- mean distance error : 1.581 ----- mean valid distance error : 0.447
# Epoch 84 ----- mean distance error : 1.578 ----- mean valid distance error : 3.544
# Epoch 85 ----- mean distance error : 1.581 ----- mean valid distance error : 0.447
# Epoch 86 ----- mean distance error : 1.578 ----- mean valid distance error : 3.544
# Epoch 87 ----- mean distance error : 1.581 ----- mean valid distance error : 0.447
# Epoch 88 ----- mean distance error : 1.578 ----- mean valid distance error : 3.544
# Epoch 89 ----- mean distance error : 1.581 ----- mean valid distance error : 0.447
# Epoch 90 ----- mean distance error : 1.578 ----- mean valid distance error : 3.544
# Epoch 91 ----- mean distance error : 1.581 ----- mean valid distance error : 0.447
# Epoch 92 ----- mean distance error : 1.578 ----- mean valid distance error : 3.544
# Epoch 93 ----- mean distance error : 1.581 ----- mean valid distance error : 3.544
# Epoch 94 ----- mean distance error : 1.581 ----- mean valid distance error : 3.544
# Epoch 95 ----- mean distance error : 1.581 ----- mean valid distance error : 3.544
# Epoch 96 ----- mean distance error : 1.581 ----- mean valid distance error : 0.447
# Epoch 97 ----- mean distance error : 1.578 ----- mean valid distance error : 3.544
# Epoch 98 ----- mean distance error : 1.581 ----- mean valid distance error : 0.447
# Epoch 99 ----- mean distance error : 1.578 ----- mean valid distance error : 3.544

# %%
# pick a trip
trip = batched_valid_dset[20]
trajectory = trip[0]
end = trip[1]

# preprocess it
trip_frac = 1.
inputs = trajectory.to(device)
targets = end.to(device)

# truncate trip to keep only beginning
inputs = inputs[:int(trip_frac*inputs.shape[0])]

# standardize inputs and targets
inputs[:,:,0] = (inputs[:,:,0] - mean_std_data["mean_lat"]) / mean_std_data["std_lat"]
inputs[:,:,1] = (inputs[:,:,1] - mean_std_data["mean_long"]) / mean_std_data["std_long"]

# predict output
output = model(inputs)

# compute mean distance error (km)
# n_pts += inputs.shape[1]

predicted_nodes = torch.argmax(output, dim=1).to('cpu').numpy()

out_long = np.zeros(len(targets))
out_lat = np.zeros(len(targets))
for i in range(len(predicted_nodes)):
    out_long[i] = model.graph.node[predicted_nodes[i]]['x']
    out_lat[i] = model.graph.node[predicted_nodes[i]]['y']

tgt_lat = targets[:,0].squeeze().to('cpu').numpy()
tgt_long = targets[:,1].squeeze().to('cpu').numpy()

# print map of Beijing
img=plt.imread('figures/map.png')
plt.figure(figsize = (24.32,31.64))
imgplot = plt.imshow(img, extent=(116.25, 116.5, 39.85, 40.1))

# plot trip, destination and predicted destination

print(trajectory[:,:,0].numpy().T)

plt.plot(trajectory[:,:,1].numpy(), trajectory[:,:,0].numpy(), 'r')
plt.scatter(trajectory[0,:,1].numpy(), trajectory[0,:,0].numpy(), c='k', marker='v', s=500, label="Trip beginning")
plt.scatter(out_long, out_lat, c='b', marker='*', s=500, label="Predicted trip end")
plt.scatter(tgt_long, tgt_lat, c='r', marker='*', s=500, label="Trip end")

plt.legend(fancybox=True)

plt.show()
# Out:
# [[40.00005  40.000057 39.999966 39.999928 40.000046 39.999912 39.999878
#   39.999886 39.99991  39.999928 39.999912 39.999905 39.999893 39.999886
#   39.999863 39.999847 39.99984  39.99985  39.999935 39.99993  39.999973
#   39.99994  40.000042 40.00015  40.000244 40.000313 40.000397 40.000492
#   40.000587 40.000706 40.00082  40.000908 40.00113  40.00125  40.00135
#   40.00147  40.001583 40.001705 40.001858 40.002052 40.002182 40.00233
#   40.00248  40.002586 40.002724 40.00283  40.00294  40.003063 40.003216
#   40.003464 40.003696 40.00388  40.004036 40.00423  40.004513 40.00473
#   40.00514  40.00558  40.00588  40.006073 40.006332 40.00654  40.00672
#   40.00694  40.007145 40.007347 40.007515 40.007797 40.008156 40.008377
#   40.008602 40.0088   40.00899  40.00915  40.009327 40.00952  40.009617
#   40.009636 40.009655 40.009674 40.009724 40.009804 40.009876 40.01005
#   40.010216 40.01031  40.01048  40.01068  40.010803 40.010876 40.010868
#   40.010906 40.01093  40.01093  40.010933 40.01097  40.01105  40.011127
#   40.011272 40.011253 40.011265 40.011265 40.011265 40.01125  40.01121
#   40.011192 40.01116  40.0111   40.011047 40.010994 40.010967 40.010952
#   40.01096  40.010963 40.010975 40.010975 40.010983]]
