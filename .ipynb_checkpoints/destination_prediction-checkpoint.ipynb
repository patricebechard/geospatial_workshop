# %%
# %pylab inline
import torch
from torch import nn
import torch.nn.functional as F
from torch import optim

import numpy as np
import os
import sys
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from src.destination_prediction.utils import *
from src.destination_prediction.model import DestinationLSTM
from src.destination_prediction.train import train, evaluate

# %% [markdown]
# we want to train 20 models with 0.05, 0.1, 0.15, 0.2, ...0.95 of all points in a trip to predict the destination and see how the prediction varies depending on the subset of data that is given. We use a multi-layer LSTM to do the prediction.
#
# Input of the neural net is the raw gps point concatenated with the timestamp.
#
# we have 3 different neural networks at the end to predict time of end of trip

# %% [markdown]
# ## Loading the data

# %% [markdown]
# Some trips are super long. we decide to keep 90% of the data (up to trips of length 2000), we also don't keep trips of length < 50.
#
# 10000 for training, 2000 for validation, 1900 for test
#
# # TODO
#
# * split dataset as train, valid, test
# * sort these by input_size for faster processing using lstm
# * preprocessing further

# %% [markdown]
# # Destination Prediction
#
# We want to predict the destination of a driver based on the beginning of its trip. We will use various subsets of the trip.

# %% [markdown]
# ### Downloading the dataset
# We first download the GeoLife Trajectories dataset from Microsoft.

# %%
download_data()
# Out:
# Data has already been downloaded!

# %% [markdown]
# ### Analyzing the trip length distribution
# We first have a look at the data to see what's the distribution of the trip lengths.

# %%
show_trip_length_distribution()
# Out:
# Creating a histogram showing the trip length distribution...

# %% [markdown]
# We decide to keep trips of length between 50 and 2000 to train our model.

# %% [markdown]
# ### Analyzing GPS position distribution
# Let's see where the majority of the trips are concentrated

# %%
show_position_distribution()
# Out:
# Creating histograms showing the position distribution...

# %% [markdown]
# We find that the majority of trips are between longitudes 116.25 and 116.50 and between latitudes 39.85 and 40.10. We decide only to keep these values. This will help use reduce the search space in order to make better predictions.

# %% [markdown]
# ### Splitting the dataset into train, valid, test sets
# This creates `train.json`, `valid.json` and `test.json` files containing the datasets.

# %%
create_datasets()
# Out:
# Splitting the dataset into train, valid, dev ...
# Standardizing the dataset...
# Saving the datasets created...

# %% [markdown]
# ### Creating our model
# We use a LSTM network as our model to predict the destination of the trip. We use this model because the length of trips varies and LSTMs can take inputs of variable lengths

# %% [markdown]
# ### Training our model
# We train the model using different fractions of the beginning of our trip.
#
# We first sort the trips of each dataset by length so that the training time is reduced a bit

# %%
import json

# loading datasets from json file
with open(os.path.join(os.getcwd(), "geolife_trajectories", "train.json")) as json_data:
    train_dset = json.load(json_data)

with open(os.path.join(os.getcwd(), "geolife_trajectories", "valid.json")) as json_data:    
    valid_dset = json.load(json_data)
    
with open(os.path.join(os.getcwd(), "geolife_trajectories", "test.json")) as json_data:
    test_dset = json.load(json_data)

# %%
#creating batched version of the datasets
batched_train_dset = create_batched_dset(train_dset)
# should not batch these datasets (reduces long term dependencies if sequences are padded too much)
batched_valid_dset = create_batched_dset(valid_dset)
batched_test_dset = create_batched_dset(test_dset)

# %%
model = DestinationLSTM().to(device)

# %%
train(model, batched_train_dset, batched_valid_dset, n_epochs=100, start_lr=1e-4, trip_frac=0.1)
# Out:
# learning rate : 0.000100
# Epoch 0 ----- mean distance error : 16.801 ----- mean valid distance error : 15.145
# learning rate : 0.000100
# Epoch 1 ----- mean distance error : 13.839 ----- mean valid distance error : 11.725
# learning rate : 0.000100
# Epoch 2 ----- mean distance error : 10.152 ----- mean valid distance error : 7.865
# learning rate : 0.000100
# Epoch 3 ----- mean distance error : 7.983 ----- mean valid distance error : 7.747
# learning rate : 0.000100
# Epoch 4 ----- mean distance error : 8.871 ----- mean valid distance error : 8.618
# learning rate : 0.000100
# Epoch 5 ----- mean distance error : 9.179 ----- mean valid distance error : 8.576
# learning rate : 0.000100
# Epoch 6 ----- mean distance error : 9.029 ----- mean valid distance error : 8.399
# learning rate : 0.000100
# Epoch 7 ----- mean distance error : 8.944 ----- mean valid distance error : 8.394
# learning rate : 0.000100
# ...

# %%
model = DestinationLSTM().to(device)
train(model, [batched_train_dset[1]], [batched_valid_dset[0]], n_epochs=1000, start_lr=1e-4)
# Out:
# learning rate : 0.000100
# Epoch 0 ----- mean distance error : 16.601 ----- mean valid distance error : 15.978
# learning rate : 0.000100
# Epoch 1 ----- mean distance error : 16.545 ----- mean valid distance error : 15.924
# learning rate : 0.000100
# Epoch 2 ----- mean distance error : 16.489 ----- mean valid distance error : 15.870
# learning rate : 0.000100
# Epoch 3 ----- mean distance error : 16.433 ----- mean valid distance error : 15.815
# learning rate : 0.000100
# Epoch 4 ----- mean distance error : 16.377 ----- mean valid distance error : 15.761
# learning rate : 0.000100
# Epoch 5 ----- mean distance error : 16.321 ----- mean valid distance error : 15.706
# learning rate : 0.000100
# Epoch 6 ----- mean distance error : 16.266 ----- mean valid distance error : 15.652
# learning rate : 0.000100
# Epoch 7 ----- mean distance error : 16.210 ----- mean valid distance error : 15.597
# learning rate : 0.000100
# ...

# %%
output = model(batched_train_dset[0][0].to('cuda'))
print(output)

# %%
print(output[0][0].item(), output[1][0].item())
print(batched_train_dset[0][1][0])
# Out:
# 40.6445426940918 116.07809448242188
# tensor([ 40.0088, 116.3218])

# %%
coord_sum = sum([torch.sum(torch.sum(batched_train_dset[i][0], dim=0), dim=0) for i in range(len(batched_train_dset))])
print(coord_sum)

n_pts = sum([torch.numel(batched_train_dset[i][0]) for i in range(len(batched_train_dset))]) / 2

print(n_pts)

lat_mean = coord_sum[0].item() / n_pts
lon_mean = coord_sum[1].item() / n_pts

print(lat_mean, lon_mean)
# Out:
# tensor([258217248., 741764672.])
# 6573584.0
# 39.28104486076393 112.84022110313035

# %%
torch.numel(torch.ones((10, 4, 2)))
# Out:
# 80

# %%
lat_sum = sum([elem['input'][0] for elem in train_dset])
lon_sum = sum([elem['input'][1] for elem in train_dset])

n_pts = sum([len(elem['input']) for elem in train_dset])

print(lat_sum)
print(lon_sum)
print(n_pts)

print("average position : %.4f, %.4f" % (lat_sum/n_pts, lon_sum/n_pts))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-efa7ca8a0473> in <module>
# ----> 1 lat_sum = sum([elem['input'][0] for elem in train_dset])
#       2 lon_sum = sum([elem['input'][1] for elem in train_dset])
#       3
#       4 n_pts = sum([len(elem['input']) for elem in train_dset])
#       5
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %%
trip = train_dset[0]

lat_sum = sum([sum([point[0] for point in trip["input"]]) for trip in train_dset])
long_sum = sum([sum([point[1] for point in trip["input"]]) for trip in train_dset])
n_pts = sum([len(trip["input"]) for trip in train_dset])
mean_lat = lat_sum/n_pts
mean_long = long_sum/n_pts
# Out:
# 258217222.9825921
# 6510734
# Average position : 39.660, 113.929

# %%
a = [1]
b = [1, 2, 3]

print(a + b)
# Out:
# [1, 1, 2, 3]

# %%
print(train_dset[0]['input'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c137012adc25> in <module>
# ----> 1 print(train_dset[0]['input'])
#
# NameError: name 'train_dset' is not defined

# %%
import os
show_position_distribution()
# Out:
# Creating histograms showing the position distribution...

# %%
import matplotlib.pyplot as plt

plt.hist(lats, range=(39.85, 40.1), bins=100)
plt.show()

# %%
plt.hist(longs, range=(116.25, 116.5), bins=100)
plt.show()

# %%
x = 0.5

lower = 39.5
upper = 40.5

x = (x * (upper - lower)) / 1 + lower

print(x)
# Out:
# 40.0
