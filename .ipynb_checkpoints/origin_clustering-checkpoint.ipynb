# %%
import osmnx
import sklearn
import pandas as pd

import os
import sys

# %%
DATADIR = "Geolife_trajectories/Data/000/Trajectory"

# %%
for file in os.listdir(DATADIR):
    
    data = pd.read_csv(os.path.join(DATADIR, file), header=6)    
    print(data.iloc[:,0].values)
    
    break
# Out:
# [40.000168 40.000055 40.000021 ... 40.011094 40.011088 40.011029]
# [40.010413 40.010114 40.010047 40.009972 40.009959 40.009884 40.009932
#  40.009938 40.01005  40.01049  40.010433 40.010502 40.010413 40.01022
#  40.010063 40.009976 40.009918 40.009899 40.009918 40.009928 40.009931
#  40.010069 40.010019 40.009883 40.009755 40.009639 40.00947  40.009437
#  40.00945  40.009456 40.009439 40.009435 40.009459 40.009415 40.009319
#  40.009162 40.008971 40.008793 40.008614 40.008448 40.008276 40.008084
#  40.00791  40.007731 40.007559 40.007376 40.007234 40.007047 40.006854
#  40.006675 40.006483 40.006291 40.006104 40.005898 40.005706 40.005551
#  40.005375 40.005202 40.004991 40.004943 40.004896 40.004884 40.004879
#  40.004974 40.005006 40.005047 40.005054 40.005054 40.005051 40.004935
#  40.004935 40.004916 40.004887 40.004809 40.004686 40.004561 40.004415
#  40.004253 40.004093 40.003895 40.003731 40.0036   40.0035   40.003489
# ...
